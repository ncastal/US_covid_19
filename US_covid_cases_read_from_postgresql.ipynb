# %%
#dependencies
import pandas as pd
import psycopg2
import sqlalchemy
from sqlalchemy import create_engine

# %%
#location for us_covid_19 postgresql database
from config import location

# %%
#create engine with location
engine=create_engine(location)

# %%
#reading database and storing it into a pandas dataframe
us_covid_19_cases_state_df=pd.read_sql('SELECT * FROM covid_19_us_cases;',engine)

# %%
us_covid_19_cases_state_df
# Out:
#       submission_date state tot_cases conf_cases prob_cases new_case  \
# 0          2020-05-04    KY      5245     5245.0          0    115.0
# 1          2020-12-08    OK    205999   171497.0      34502      0.0
# 2          2020-08-21    MD    103523       None       None    624.0
# 3          2020-04-01    MN       742       None       None     53.0
# 4          2020-06-25    NE     18346       None       None    125.0
# ...               ...   ...       ...        ...        ...      ...
# 22135      2020-10-28    OR     43228    41508.0       1720    420.0
# 22136      2020-09-06    OR     28044    26737.0       1307    188.0
# 22137      2020-10-19    KS     72968    67935.0       5033   2113.0
# 22138      2020-02-26    KS         0       None       None      0.0
# 22139      2020-08-06    NC    132512   131267.0       1245   2049.0
#
#       pnew_case tot_death conf_death prob_death new_death pnew_death  \
# ...
